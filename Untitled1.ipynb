# %%
2.1 import pandas as pd

# Example: Creating a sample DataFrame
data = {'Name': ['John', 'Anna', 'Peter', 'Linda'],
        'Age': [28, 24, 35, 32],
        'City': ['New York', 'Paris', 'Berlin', 'London']}

df = pd.DataFrame(data)

# Get the number of rows and columns
rows, columns = df.shape

# Display the result
print(f"The DataFrame has {rows} rows and {columns} columns.")
2.2 a observation is a certain category in the dataset, it is usually one row of data.
variables is the characteristic of the a category of data, it is usually one colomn of data.
3. import pandas as pd

# Example: Creating a sample DataFrame
data = {'Name': ['John', 'Anna', 'Peter', 'Linda'],
        'Age': [28, 24, 35, 32],
        'City': ['New York', 'Paris', 'Berlin', 'London']}

df = pd.DataFrame(data)

# Get descriptive statistics for numeric columns
print("Descriptive statistics for numeric columns:")
print(df.describe())

# Get a summary of all columns including non-numeric ones
print("\nDescriptive statistics including non-numeric columns:")
print(df.describe(include='all'))

# Get general info about the DataFrame (e.g., number of columns, data types)
print("\nGeneral information about the DataFrame:")
print(df.info())
 
    4. import pandas as pd

# Example: Creating a sample DataFrame with numeric and non-numeric columns and missing values
data = {'Name': ['John', 'Anna', 'Peter', 'Linda'],
        'Age': [28, 24, None, 32],   # 'None' represents missing values in the 'Age' column
        'City': ['New York', 'Paris', 'Berlin', None]}  # Missing value in 'City'

df = pd.DataFrame(data)

# 1. Finding non-numeric (categorical) variables
non_numeric_columns = df.select_dtypes(exclude=['number']).columns
print("Non-numeric (categorical) columns:")
print(non_numeric_columns)

# 2. Finding missing values in the dataset
missing_values = df.isnull().sum()
print("\nMissing values in each column:")
print(missing_values)

# Optional: Display only columns with missing values
print("\nColumns with missing values:")
print(missing_values[missing_values > 0])

chatgpt history：https://chatgpt.com/c/66e24d72-0528-8012-9339-28b1de6b98fc
